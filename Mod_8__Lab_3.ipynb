# %% [markdown]
# <a href="https://colab.research.google.com/github/Nallasailaja/FMML-/blob/main/Mod_8__Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-13 13:01:39--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  79.3MB/s    in 0.9s
#
# 2025-03-13 13:01:42 (79.3 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 5929    1302.6452v1  This paper applies conformal prediction techni...  stat
# 22333  1602.03683v1  The mixture of experts (MoE) model is a popula...  stat
# 22840  1708.05257v1  Bayesian models that mix multiple Dirichlet pr...  stat
# 7631   1802.05799v3  Training modern deep learning models requires ...    cs
# 35275  cs/0211028v1  In this paper we name some of the advantages o...    cs
# ...             ...                                                ...   ...
# 25487  1509.05195v1  Quantization methods have been introduced to p...    cs
# 6757   1705.10359v1  Neural embeddings have been used with great su...  stat
# 11405  1512.08065v4  We propose a new approach to inverse reinforce...    cs
# 1965   1701.02343v1  Despite enormous progress in object detection ...    cs
# 21734   1406.0873v2  Linear dimensionality reduction methods are a ...  stat
#
#                                                    title  year  \
# 5929   A Conformal Prediction Approach to Explore Fun...  2013
# 22333  A Universal Approximation Theorem for Mixture ...  2016
# 22840     Auxiliary Variables for Multi-Dirichlet Priors  2017
# 7631   Horovod: fast and easy distributed deep learni...  2018
# 35275  Thinking Adaptive: Towards a Behaviours Virtua...  2002
# ...                                                  ...   ...
# 25487  Improved Residual Vector Quantization for High...  2015
# 6757     Neural Embeddings of Graphs in Hyperbolic Space  2017
# 11405  Inverse Reinforcement Learning via Deep Gaussi...  2015
# 1965   Information Pursuit: A Bayesian Framework for ...  2017
# 21734  Linear Dimensionality Reduction: Survey, Insig...  2014
#
#                                                 keywords
# 5929   [conformal, prediction, techniques, simultaneo...
# 22333  [architecture, nonlinear, regression, classifi...
# 22840  [dirichlet, parameters, dirichlet, popularity,...
# 7631   [computation, computation, complications, comm...
# 35275  [advantages, laboratories, behaviours, laborat...
# ...                                                  ...
# 25487  [quantization, introduced, approximate, quanti...
# 6757   [embeddings, processing, representations, enca...
# 11405  [reinforcement, complicated, structures, demon...
# 1965   [detection, classification, incorporating, con...
# 21734  [dimensionality, reduction, cornerstone, analy...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 5929     [conformal, prediction, techniques, simultaneo...
# 22333    [architecture, nonlinear, regression, classifi...
# 22840    [dirichlet, parameters, dirichlet, popularity,...
# 7631     [computation, computation, complications, comm...
# 35275    [advantages, laboratories, behaviours, laborat...
#                                ...
# 25526    [algorithm, bootstrap, initialized, background...
# 12921    [approximate, computation, synthetic, likeliho...
# 30170    [prominence, representing, irregular, challeng...
# 28993    [complication, amputation, depending, patholog...
# 11860    [stochastic, recursive, algorithm, practical, ...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8797 words.
# Out of those 4624 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="32f572b7-32d1-47c0-b2f5-41a7d5d8d477" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32f572b7-32d1-47c0-b2f5-41a7d5d8d477")) {                    Plotly.newPlot(                        "32f572b7-32d1-47c0-b2f5-41a7d5d8d477",                        [{"x":["stochastic","predictor","functional","computational","clustering","techniques","simultaneous","assumptions","distributional","informative","underlying","guaranteed","prediction","conformal","computation","correspond","illustrated","inductive","nonlinear","differentiable","functions","classification","convergent","sufficiently","continuous","approximation","architecture","regression","hypercube","estimation","arbitrary","uniformly","universal","alternative","collapsed","complicate","efficient","distribution","involving","dirichlet","inferring","distributions","hierarchical","auxiliary","inference","popularity","parameters","variables","complications","reduction","introduce","advantage","tensorflow","significant","distributed","particular","communication","negligible","modification","depending","available","researchers","advantages","laboratory","understanding","development","illustrate","behaviour","properties","behaviours","selection","experiments","perspective","conditional","nonparametric","autoregressive","conditions","components","analytical","correctly","observations","parametric","graphical","dimensional","smoothness","probability","compressive","combinatorial","detection","translation","embedding","connecting","relations","competitive","demonstrate","predicate","relationship","convolutional","effectiveness","extraction","comprehensive","representation","complexity","knowledge","challenging","relational","trivially","datapoints","technique","additionally","objectives","retaining","inversely","proportionally","generalization","translates","parallelized","independent","posterior","convergence","parallelizability","reparameterization","demonstrated","gradients","posteriors","investigate","variational","uncertainty","specifically","minibatch","invariant","parameterized","generally","connection","proportional","annotations","projective","plausible","framework","requiring","synthetic","disentangled","approaches","sequentially","introduces","trainable","appearance","information","determined","reconstruction","therefore","performance","challenges","variations","including","formulation","realistic","recovered","adaptation","estimates","automatically","dimension","anopheles","validation","collected","treatment","associated","automatic","epidemiology","estimators","expertise","interactions","explanatory","environmental","certainly","sophisticated","exemplary","consistent","attention","comparison","prioritization","simulation","methodology","preferences","solutions","significantly","perfectly","deteriorate","consistency","algorithms","processes","hierarchy","procedures","improvement","contemporary","procedure","important","judgments","developing","reinterpret"],"y":[130,20,47,303,156,344,32,64,19,39,110,28,231,0,165,26,22,23,66,32,209,489,4,17,112,128,250,112,0,197,82,13,47,101,2,1,397,209,44,21,24,119,103,18,217,20,245,127,3,105,343,111,2,249,104,269,78,9,35,47,300,74,93,9,155,120,78,40,201,12,162,583,68,101,20,2,132,97,27,28,57,58,57,189,20,166,17,32,318,107,127,14,92,131,601,11,76,343,199,141,59,376,206,372,276,29,1,2,238,70,26,9,1,1,98,9,4,145,42,115,1,2,106,34,3,149,53,76,165,0,66,12,80,34,13,50,7,35,549,36,126,9,392,20,73,36,73,711,41,109,147,879,122,72,265,94,64,9,61,64,172,72,0,47,68,24,103,178,0,14,7,60,3,18,3,37,2,90,161,132,2,75,66,35,147,265,7,1,55,565,96,38,25,130,14,121,343,10,55,3],"type":"bar"},{"x":["stochastic","predictor","functional","computational","cl ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4624,), (4624, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8075

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.41333333333333333);'>Improving</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Performance</span> <span style=''>of</span> <span style=''>Online</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>Transducer</span> <span style=''>Models</span> <br/><br/><span style=''>Having</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>model</span> <span style=''>which</span> <span style=''>can</span> <span style=''>operate</span> <span style=''>in</span> <span style=''>an</span> <span style=''>online</span> <span style=''>fashion</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3157894736842105);'>streaming</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applications</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Voice</span> <span style=''>Search</span> <span style=''>Neural</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>transducer</span> <span style=''>is</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3157894736842105);'>streaming</span> <span style=''>sequence</span> <span style=''>to</span> <span style=''>sequence</span> <span style=''>model</span> <span style=''>but</span> <span style=''>has</span> <span style=''>shown</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3387096774193548);'>significant</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>degradation</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3157894736842105);'>streaming</span> <span style=''>models</span> <span style=''>such</span> <span style=''>as</span> <span style=''>Listen</span> <span style=''>Attend</span> <span style=''>and</span> <span style=''>Spell</span> <span style=''>(LAS)</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>various</span> <span style='background-color:rgba(0, 255, 0, 0.42528735632183917);'>improvements</span> <span style=''>to</span> <span style=''>NT</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>look</span> <span style=''>at</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>increasing</span> <span style=''>the</span> <span style=''>window</span> <span style=''>over</span> <span style=''>which</span> <span style=''>NT</span> <span style=''>computes</span> <span style='background-color:rgba(0, 255, 0, 0.4122807017543861);'>attention</span> <span style=''>mainly</span> <span style=''>by</span> <span style=''>looking</span> <span style=''>backwards</span> <span style=''>in</span> <span style=''>time</span> <span style=''>so</span> <span style=''>the</span> <span style=''>model</span> <span style=''>still</span> <span style=''>remains</span> <span style=''>online</span> <span style=''>In</span> <span style=''>addition</span> <span style=''>we</span> <span style=''>explore</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>initializing</span> <span style=''>a</span> <span style=''>NT</span> <span style=''>model</span> <span style=''>from</span> <span style=''>a</span> <span style=''>LAS</span> <span style=''>trained</span> <span style=''>model</span> <span style=''>so</span> <span style=''>that</span> <span style=''>it</span> <span style=''>is</span> <span style=''>guided</span> <span style=''>with</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color: ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Relations</span> <span style=''>Between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Adjacency</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Modularity</span> <span style=''>Graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Partitioning</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>the</span> <span style=''>exact</span> <span style=''>linear</span> <span style=''>relation</span> <span style=''>between</span> <span style=''>the</span> <span style=''>leading</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvector</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unnormalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modularity</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvectors</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style=''>matrix</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>developed</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>this</span> <span style=''>analysis</span> <span style=''>a</span> <span style=''>method</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>the</span> <span style=''>leading</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>eigenvector</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modularity</span> <span style=''>matrix</span> <span style=''>is</span> <span style=''>given</span> <span style=''>and</span> <span style=''>the</span> <span style=''>relative</span> <span style=''>error</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>is</span> <span style=''>derived</span> <span style=''>A</span> <span style=''>complete</span> <span style=''>proof</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalence</span> <span style=''>between</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalized</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>modularity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>normalized</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>adjacency</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>is</span> <span style=''>also</span> <span style=''>given</span> <span style=''>A</span> <span style=''>new</span> <span style=''>metric</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>to</span> <span style=''>describe</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>agreement</span> <span style=''>of</span> <span style=''>two</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style=''>methods</span> <span style=''>and</span> <span style=''>some</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experiments</span> <span style=''>are</span> <span style=''>given</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>illustrate</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corroborate</span> <span style=''>the</span> <span style=''>points</span> <span style=''>that</span> <span style=''>are</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.4761904761904761);'>Nonconvex</span> <span style=''>Sparse</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Alternating</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Direction</span> <span style=''>Method</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Multipliers</span> <span style=''>and</span> <span style=''>Its</span> <span style='background-color:rgba(255, 0, 0, 0.3175074183976261);'>Convergence</span> <span style=''>Analysis</span> <br/><br/><span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>(SC)</span> <span style=''>is</span> <span style=''>a</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>method</span> <span style=''>which</span> <span style=''>first</span> <span style=''>learns</span> <span style=''>a</span> <span style=''>low</span> <span style='background-color:rgba(255, 0, 0, 0.32136445242369827);'>dimensional</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>embedding</span> <span style=''>U</span> <span style=''>of</span> <span style=''>data</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.6296296296296297);'>eigenvectors</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>normalized</span> <span style='background-color:rgba(255, 0, 0, 0.31914893617021267);'>Laplacian</span> <span style=''>matrix</span> <span style=''>and</span> <span style=''>then</span> <span style=''>performs</span> <span style=''>k</span> <span style=''>means</span> <span style=''>on</span> <span style=''>Utop</span> <span style=''>to</span> <span style=''>get</span> <span style=''>the</span> <span style=''>final</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>result</span> <span style=''>The</span> <span style=''>Sparse</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>(SSC)</span> <span style=''>method</span> <span style=''>extends</span> <span style=''>SC</span> <span style=''>with</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>on</span> <span style=''>UUtop</span> <span style=''>by</span> <span style=''>using</span> <span style=''>the</span> <span style=''>block</span> <span style=''>diagonal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structure</span> <span style=''>prior</span> <span style=''>of</span> <span style=''>UUtop</span> <span style=''>in</span> <span style=''>the</span> <span style=''>ideal</span> <span style=''>case</span> <span style=''>However</span> <span style='background-color:rgba(0, 255, 0, 0.3125);'>encouraging</span> <span style=''>UUtop</span> <span style=''>to</span> <span style=''>be</span> <span style=''>sparse</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>a</span> <span style=''>heavily</span> <span style='background-color:rgba(255, 0, 0, 0.4761904761904761);'>nonconvex</span> <span style=''>problem</span> <span style=''>which</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.4412532637075718);'>challenging</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>and</span> <span style=''>the</span> <span style=''>work</span> <span style=''>(Lu</span> <span style=''>Yan</span> <span style=''>and</span> <span style=''>Lin</span> <span style=''>2016)</span> <span style=''>proposes</span> < ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Statistical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Inference</span> <span style=''>in</span> <span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>Models</span> <span style=''>using</span> <span style=''>k</span> <span style=''>segment</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constraints</span> <br/><br/><span style=''>Hidden</span> <span style=''>Markov</span> <span style=''>models</span> <span style=''>(HMMs)</span> <span style=''>are</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>widely</span> <span style=''>used</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistical</span> <span style=''>methods</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analyzing</span> <span style=''>sequence</span> <span style=''>data</span> <span style=''>However</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reporting</span> <span style=''>of</span> <span style=''>output</span> <span style=''>from</span> <span style=''>HMMs</span> <span style=''>has</span> <span style=''>largely</span> <span style=''>been</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>restricted</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>presentation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>most</span> <span style=''>probable</span> <span style=''>(MAP)</span> <span style=''>hidden</span> <span style=''>state</span> <span style=''>sequence</span> <span style=''>found</span> <span style=''>via</span> <span style=''>the</span> <span style=''>Viterbi</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>or</span> <span style=''>the</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>most</span> <span style=''>probable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>marginals</span> <span style=''>using</span> <span style=''>the</span> <span style=''>forward</span> <span style=''>backward</span> <span style=''>(F</span> <span style=''>B)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>In</span> <span style=''>this</span> <span style=''>article</span> <span style=''>we</span> <span style=''>expand</span> <span style=''>the</span> <span style=''>amount</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>we</span> <span style=''>could</span> <span style=''>obtain</span> <span style=''>from</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distribution</span> <span style=''>of</span> <span style=''>an</span> <span style=''>HMM</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>linear</span> <span style=''>time</span> <span style=''>dynamic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>programming</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collectively</span> <span style=''>call</span> <span style=''>k</span> <span style=''>segment</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>that</span> <span style=''>allow</span> <span style=''>us</span> <span style=''>to</span> <span style=''>i)</span> <span style=''>find</span> <span style=''>MAP</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sequences</span> <span style=''>ii)</span> <span style=''>compute</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>posterior</span> <span style=' ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	experimental (0.13304721030042918)
# 	architecture (0.08941344778254649)
# 	segmentation (0.0736766809728183)
# 	representation (0.13447782546494993)
# 	knowledge (0.13304721030042918)
# 	detection (0.11373390557939914)
# 	information (0.2542918454935622)
# 	convolutional (0.1226752503576538)
# 	different (0.2821888412017167)
# 	recognition (0.1473533619456366)
#
# Some Statistics words are:
# 	variational (0.1027944111776447)
# 	algorithm (0.38672654690618763)
# 	theoretical (0.14820359281437126)
# 	estimation (0.17015968063872255)
# 	statistical (0.16117764471057885)
# 	variables (0.1472055888223553)
# 	distribution (0.18363273453093812)
# 	dimensional (0.18363273453093812)
# 	inference (0.2000998003992016)
# 	regression (0.18213572854291418)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="9124dff4-5806-40dd-aec5-fa64c7fad6d1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9124dff4-5806-40dd-aec5-fa64c7fad6d1")) {                    Plotly.newPlot(                        "9124dff4-5806-40dd-aec5-fa64c7fad6d1",                        [{"x":["stochastic","predictor","functional","computational","clustering","techniques","simultaneous","assumptions","distributional","informative","underlying","guaranteed","prediction","conformal","computation","correspond","illustrated","inductive","nonlinear","differentiable","functions","classification","convergent","sufficiently","continuous","approximation","architecture","regression","hypercube","estimation","arbitrary","uniformly","universal","alternative","collapsed","complicate","efficient","distribution","involving","dirichlet","inferring","distributions","hierarchical","auxiliary","inference","popularity","parameters","variables","complications","reduction","introduce","advantage","tensorflow","significant","distributed","particular","communication","negligible","modification","depending","available","researchers","advantages","laboratory","understanding","development","illustrate","behaviour","properties","behaviours","selection","experiments","perspective","conditional","nonparametric","autoregressive","conditions","components","analytical","correctly","observations","parametric","graphical","dimensional","smoothness","probability","compressive","combinatorial","detection","translation","embedding","connecting","relations","competitive","demonstrate","predicate","relationship","convolutional","effectiveness","extraction","comprehensive","representation","complexity","knowledge","challenging","relational","trivially","datapoints","technique","additionally","objectives","retaining","inversely","proportionally","generalization","translates","parallelized","independent","posterior","convergence","parallelizability","reparameterization","demonstrated","gradients","posteriors","investigate","variational","uncertainty","specifically","minibatch","invariant","parameterized","generally","connection","proportional","annotations","projective","plausible","framework","requiring","synthetic","disentangled","approaches","sequentially","introduces","trainable","appearance","information","determined","reconstruction","therefore","performance","challenges","variations","including","formulation","realistic","recovered","adaptation","estimates","automatically","dimension","anopheles","validation","collected","treatment","associated","automatic","epidemiology","estimators","expertise","interactions","explanatory","environmental","certainly","sophisticated","exemplary","consistent","attention","comparison","prioritization","simulation","methodology","preferences","solutions","significantly","perfectly","deteriorate","consistency","algorithms","processes","hierarchy","procedures","improvement","contemporary","procedure","important","judgments","developing","reinterpret","existence","templates","parameter","dynamical","equations","classical","management","clinicians","presented","computing","diagnostic","discusses","departments","statistics","combination","describes","statistical","induction","undertaken","essentially","comparisons","diagnosis","robustness","incompleteness","decompose","conducted","decisions","limitations","recommendation","considering","reactions","diagnoses","extensive","benefiting","medicines","embeddings","corresponding","heterogeneous","electronic","caregivers","assisting","constructs","conventional","tomographic","numerical","regularization","attenuation","coefficients","traditional","scattered","recovering","absorption","preserving","comparing","optimization", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	conformal
# 	hypercube
# 	minibatch
# 	anopheles
# 	epidemiology
# 	economists
# 	regulating
# 	disentanglement
# 	thetastar
# 	autoimmune
# 	scleroderma
# 	disregarding
# 	oscillations
# 	interchangeable
# 	gribonval
# 	convincingly
# 	workhorse
# 	discretizations
# 	newtonian
# 	negativity
# Some words which never appear in Statistics papers:
# 	complications
# 	incompleteness
# 	benefiting
# 	medicines
# 	caregivers
# 	tomographic
# 	attenuation
# 	quickbird
# 	discourse
# 	syntactically
# 	connectives
# 	conflicting
# 	dialectical
# 	argumentation
# 	defeasible
# 	localizing
# 	synchronized
# 	geography
# 	emoticons
# 	configure

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.068990915786889e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7725
